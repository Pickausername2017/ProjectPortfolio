# %%
import requests
import pandas as pd

# %%
url= 'https://api.setlist.fm/rest/1.0/artist/94f8947c-2d9c-4519-bcf9-6d11a24ad006/setlists?p=10'
headers = {'x-api-key': 't2Somj7oKPv87t_0mxlzCjbBX3_YdXRukA3N'}

# %%
r = requests.get(url, headers=headers)

# %%
r.text
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?>\n<setlists itemsPerPage="20" page="10" total="202">\n    <setlist id="7bf27e94" versionId="1b2bcde0" eventDate="31-12-2015" lastUpdated="2020-10-30T09:41:48.000+0000">\n        <artist mbid="94f8947c-2d9c-4519-bcf9-6d11a24ad006" name="Dead &amp; Company" sortName="Dead &amp; Company" disambiguation="">\n            <url>https://www.setlist.fm/setlists/dead-and-company-2bc42076.html</url>\n        </artist>\n        <venue id="7bd3cea4" name="The Forum">\n            <city id="5359488" name="Inglewood" state="California" stateCode="CA">\n                <coords lat="33.9616801" long="-118.3531311"/>\n                <country code="US" name="United States"/>\n            </city>\n            <url>https://www.setlist.fm/venue/the-forum-inglewood-ca-usa-7bd3cea4.html</url>\n        </venue>\n        <tour name="2015 U.S. Tour"/>\n        <sets>\n            <set name="Set 1:">\n                <song name="Feel Like a Stranger">\n  
# ...

# %%
r.to_csv (r'C:\Users\denis\Desktop\export_dataframe.csv', index = False, header=True)

print (r)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8376/1268114677.py in <module>
# ----> 1 r.to_csv (r'C:\Users\denis\Desktop\export_dataframe.csv', index = False, header=True)
#       2
#       3 print (r)
#
# AttributeError: 'Response' object has no attribute 'to_csv'
